# %% [markdown]
# # Step 1: Data Collection
# Run this notebook to capture video from your webcam, extract MediaPipe hand/body coordinates, and save them as numpy arrays (.npy) into the `dataset/extracted_landmarks/` folder.
