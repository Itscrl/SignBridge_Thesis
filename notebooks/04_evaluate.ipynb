# %% [markdown]
# # Step 4: Model Evaluation
# Run this notebook to load the test dataset, generate predictions using your trained LSTM, and plot Confusion Matrices and Accuracy scores using Matplotlib/Seaborn.
