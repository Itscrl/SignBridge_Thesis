# %% [markdown]
# # Step 3: Train the LSTM Model
# Run this notebook to define your Keras LSTM architecture, train the model using your preprocessed sequences, and save the final model as `.h5` into the `saved_models/` directory.
